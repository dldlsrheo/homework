# %%
import h5py
import pandas as pd
import os
import tables
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
h5file = tables.open_file('/home/yjh/homework/particles_0000.h5','r')

# %%
h5file.root.particles
# Out:
# /particles (EArray(50000, 7)) ''
#   atom := Float64Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (12500, 7)

# %%
h5file.root.particles.read()
# Out:
# array([[-1.21539686e-03, -4.77059813e-04, -1.46822690e-02, ...,
#          4.39173925e-03,  1.10865090e-04,  0.00000000e+00],
#        [ 9.47188450e-03,  9.31982835e-04, -1.31318256e-03, ...,
#          2.40833085e-03,  2.18614690e-04,  1.00000000e+00],
#        [ 8.41932706e-03,  2.92489828e-04, -3.12941853e-03, ...,
#          3.50049721e-03,  5.02158868e-05,  2.00000000e+00],
#        ...,
#        [ 1.68872362e-02,  1.40635777e-03,  3.46865777e-03, ...,
#         -7.01113643e-04,  2.54621360e-06,  4.99970000e+04],
#        [ 2.41185827e-02,  1.77260996e-03, -7.08447329e-03, ...,
#          2.05839011e-03, -5.29003355e-05,  4.99980000e+04],
#        [-1.68548920e-02, -9.82746655e-04, -9.55721908e-04, ...,
#          5.45156387e-03,  5.13192608e-04,  4.99990000e+04]])

# %%
particles = h5file.root.particles

# %%
x = particles[:,0]

# %%
x_prime = particles[:,1]

# %%
y = particles[:,2]

# %%
y_prime = particles[:,3]

# %%
fig = plt.figure(figsize = (20,20))

# %%
plt.figure(figsize = (10,10))
grid = plt.GridSpec(2, 2, height_ratios=[1,4], width_ratios=[4,1])

plt.subplot(grid[0, 0])
plt.hist(x,bins=100)
plt.title('')
plt.xlabel('')
plt.ylabel('')
plt.grid()


plt.subplot(grid[1, 0])      
plt.scatter(x,x_prime, s = 0.1)
plt.title('x,x_prime')
plt.xlabel('x')
plt.ylabel('x_prime')
plt.grid()


plt.subplot(grid[1, 1])
plt.hist( x_prime, bins=100, orientation = 'horizontal')
plt.title('')
plt.xlabel('')
plt.ylabel('')
plt.grid()

plt.tight_layout()

plt.show()

# %%
h5file.close()
particles.close()
